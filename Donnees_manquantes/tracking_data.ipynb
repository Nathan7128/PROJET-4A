# %% [markdown]
# # Importation des données

# %%
import sqlite3
import pandas as pd

# %%
connect = sqlite3.connect("../Databases/raw-database.db")
cursor = connect.cursor()

# %%
req = cursor.execute(f"SELECT * FROM tracking_data")
res = req.fetchall()
desc = req.description
tracking_data = pd.DataFrame(res)
tracking_data.columns = [i[0] for i in desc]

# %%
nb_tracking_data = len(tracking_data)
nb_tracking_data
# Out:
# 467914

# %% [markdown]
# ---
# # Etudes des colonnes comportant des valeurs Nan

# %%
tracking_data.isna().any()
# Out:
# track_id            False
# trackable_object    False
# is_visible          False
# x                   False
# y                   False
# vx                   True
# vy                   True
# speed_norm           True
# accel_norm           True
# z                    True
# frame               False
# match_id_SKC        False
# dtype: bool

# %% [markdown]
# ---
# # Etude des colonnes "vx", "vy", "speed_norm" et "accel_norm" pour le ballon (trackable_object 55)

# %%
print(tracking_data[tracking_data.trackable_object == 55].vx.unique(),
      tracking_data[tracking_data.trackable_object == 55].vy.unique(),
      tracking_data[tracking_data.trackable_object == 55].speed_norm.unique(),
      tracking_data[tracking_data.trackable_object == 55].accel_norm.unique())
# Out:
# [nan] [nan] [nan] [nan]

# %% [markdown]
# On remarque que ces colonnes ne contiennent que des valeurs nan pour le ballon : on ne lui attribue ni vitesse, ni acceleration

# %% [markdown]
# ---
# # Etudes des valeurs Nan pour la colonne "vx" et "vy" hormis pour le ballon

# %%
# Index des tracks correspondants a des valeurs Nan
index = tracking_data.index[((tracking_data.vx.isna()) | (tracking_data.vy.isna())) & (tracking_data.trackable_object != 55)]

# %%
tracking_data.loc[index]
# Out:
#         track_id  trackable_object  is_visible      x      y  vx  vy  \
# 250828   33027.0           33027.0           0  41.10   5.89 NaN NaN
# 264174   34965.0           34965.0           0 -31.76  -1.28 NaN NaN
# 264175   33027.0           33027.0           0   0.39 -14.57 NaN NaN
# 264176   20484.0           20484.0           0   2.38  -5.36 NaN NaN
# 264177   13578.0           13578.0           0  11.29  -3.05 NaN NaN
# 264178    7387.0            7387.0           1  35.86 -20.01 NaN NaN
# 264179   25486.0           25486.0           0  17.50   6.91 NaN NaN
# 264180    7350.0            7350.0           0  19.82   2.87 NaN NaN
# 264181   18582.0           18582.0           1  21.49 -15.21 NaN NaN
# 264182   28840.0           28840.0           1  38.98  -9.61 NaN NaN
# 264183   17913.0           17913.0           1  43.72   6.75 NaN NaN
# 264184    4102.0            4102.0           1  40.04   0.04 NaN NaN
# 264185   32039.0           32039.0           1  51.41  -4.73 NaN NaN
# 264186  153787.0          153787.0           1  47.19   4.90 NaN NaN
# 264187  181549.0          181549.0           1  48.38 -16.70 NaN NaN
# 264188  159756.0          159756.0           1  38.41  12.26 NaN NaN
# 264189   25959.0           25959.0           1  37.86 -26.22 NaN NaN
# 264190    1277.0            1277.0           1  33.70  -4.82 NaN NaN
# 264191    7842.0            7842.0           1  35.95  -6.92 NaN NaN
# 264192    8933.0            8933.0           0  18.43   1.83 NaN NaN
# 264193   12742.0           12742.0           1  26.11  -9.03 NaN NaN
# 264194   34782.0           34782.0           0  12.99 -13.73 NaN NaN
# 264195  172065.0          172065.0           0  15.58  -9.31 NaN NaN
#
#         speed_norm  accel_norm   z  frame  match_id_SKC
# 250828         NaN         NaN NaN  72949       1377411
# 264174         NaN         NaN NaN  72579       1385352
# 264175         NaN         NaN NaN  72579       1385352
# 264176         NaN         NaN NaN  72579       1385352
# 264177         NaN         NaN NaN  72579       1385352
# 264178         NaN         NaN NaN  72579       1385352
# 264179         NaN         NaN NaN  72579       1385352
# 264180         NaN         NaN NaN  72579       1385352
# 264181         NaN         NaN NaN  72579       1385352
# 264182         NaN         NaN NaN  72579       1385352
# 264183         NaN         NaN NaN  72579       1385352
# 264184         NaN         NaN NaN  72579       1385352
# 264185         NaN         NaN NaN  72579       1385352
# 264186         NaN         NaN NaN  72579       1385352
# 264187         NaN         NaN NaN  72579       1385352
# 264188         NaN         NaN NaN  72579       1385352
# 264189         NaN         NaN NaN  72579       1385352
# 264190         NaN         NaN NaN  72579       1385352
# 264191         NaN         NaN NaN  72579       1385352
# 264192         NaN         NaN NaN  72579       1385352
# 264193         NaN         NaN NaN  72579       1385352
# 264194         NaN         NaN NaN  72579       1385352
# 264195         NaN         NaN NaN  72579       1385352

# %% [markdown]
# Nous n'avons pas beaucoup d'informations concernant les valeurs manquantes pour ces colonnes.
# Cependant, grâce à la documentation ci-dessous, nous pouvons deviner que ces valeurs "nan" font référence à des tracks d'objet dont on dispose moins de 5 frames, donc Skill Corner ne peut pas calculer la vitesse de l'objet sur le track en question.
#
# Source : https://skillcorner.crunch.help/en/glossaries/coordinates-distance-speeds-and-directions
