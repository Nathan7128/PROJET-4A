# %%
import pandas as pd

# %%
df = pd.read_json("Projet_centres_data/SKC_crosses_freeze_frames/1483176.json")

# %%
df.columns
# Out:
# Index(['data', 'possession', 'frame', 'image_corners_projection', 'timestamp',
#        'period', 'event_id', 'event_x', 'event_y', 'is_matched'],
#       dtype='object')

# %%
df
# Out:
#                                                  data  \
# 0   [{'track_id': 928, 'trackable_object': 928, 'i...
# 1   [{'track_id': 928, 'trackable_object': 928, 'i...
# 2   [{'track_id': 928, 'trackable_object': 928, 'i...
# 3   [{'track_id': 928, 'trackable_object': 928, 'i...
# 4   [{'track_id': 928, 'trackable_object': 928, 'i...
# ..                                                ...
# 61  [{'track_id': 928, 'trackable_object': 928, 'i...
# 62  [{'track_id': 928, 'trackable_object': 928, 'i...
# 63  [{'track_id': 928, 'trackable_object': 928, 'i...
# 64  [{'track_id': 928, 'trackable_object': 928, 'i...
# 65  [{'track_id': 928, 'trackable_object': 928, 'i...
#
#                                            possession  frame  \
# 0    {'group': 'away team', 'trackable_object': None}   9451
# 1    {'group': 'away team', 'trackable_object': None}   9479
# 2    {'group': 'away team', 'trackable_object': None}   9491
# 3    {'group': 'away team', 'trackable_object': 9451}  13308
# ...

# %%
df.data.iloc[0]
# Out:
# [{'track_id': 928,
#   'trackable_object': 928,
#   'is_visible': False,
#   'x': 28.84,
#   'y': -0.43,
#   'vx': -0.40447635419826106,
#   'vy': -0.9588667543061061,
#   'speed_norm': 1.040685626699554,
#   'accel_norm': -0.07281080723180701},
#  {'track_id': 174557,
#   'trackable_object': 174557,
#   'is_visible': False,
#   'x': -8.24,
#   'y': 11.01,
#   'vx': -0.8928759227424171,
#   'vy': -1.453925236795052,
#   'speed_norm': 1.70620221767605,
#   'accel_norm': -0.32692043384991304},
#  {'track_id': 11335,
#   'trackable_object': 11335,
#   'is_visible': False,
#   'x': -9.2,
#   'y': -1.04,
#   'vx': -1.025100279772113,
#   'vy': -1.951078639565795,
#   'speed_norm': 2.203982404956714,
#   'accel_norm': 0.334915072543704},
#  {'track_id': 11608,
#   'trackable_object': 11608,
#   'is_visible': False,
#   'x': -22.29,
#   'y': 14.88,
#   'vx': -1.2101408972932561,
#   'vy': -1.627373849731978,
#   'speed_norm': 2.028000650417353,
#   'accel_norm': 0.197612299094265},
# ...
