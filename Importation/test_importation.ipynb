# %%
import pandas as pd
import sqlite3

# %%
connect = sqlite3.connect("raw-database.db")

# %%
SKC_matches_data_2 = pd.read_json("Projet_centres_data/data_add/SKC_matches_data_2.json")

# %%
SKC_matches_data_2
# Out:
#          1547880        1547881        1547882        1547883        1547884  \
# 0  left_to_right  right_to_left  right_to_left  left_to_right  left_to_right
# 1  right_to_left  left_to_right  left_to_right  right_to_left  right_to_left
#
#          1547885        1547886        1547887        1547888        1536669  \
# 0  right_to_left  right_to_left  right_to_left  right_to_left  right_to_left
# 1  left_to_right  left_to_right  left_to_right  left_to_right  left_to_right
#
#    ...        1034262        1024091        1023376        1022715  \
# 0  ...  left_to_right  left_to_right  right_to_left  right_to_left
# 1  ...  right_to_left  right_to_left  left_to_right  left_to_right
#
#          1023377        1028727        1022717        1021411        1020753  \
# 0  right_to_left  left_to_right  right_to_left  right_to_left  left_to_right
# 1  left_to_right  right_to_left  left_to_right  left_to_right  right_to_left
#
#          1020089
# 0  right_to_left
# 1  left_to_right
#
# ...

# %%
freeze_frames = pd.read_json("Projet_centres_data/SKC_crosses_freeze_frames/1020089.json")

# %%
pd.DataFrame(freeze_frames.iloc[0].data)
# Out:
#     track_id  trackable_object  is_visible      x      y        vx        vy  \
# 0      12235             12235        True  45.43  -0.97  2.594984  0.087762
# 1      12327             12327        True  32.26  -2.78  5.386337 -0.666400
# 2       2340              2340        True  33.55 -16.15  5.579671 -0.015822
# 3      12788             12788        True  30.18   5.24  6.059448 -1.084029
# 4      25539             25539        True  30.43 -24.45  5.782475 -0.472854
# 5      28826             28826        True  25.73 -17.81  5.064216  1.340289
# 6      20395             20395        True  13.19 -18.72  3.851392  0.650158
# 7       7771              7771        True  19.47 -12.85  4.526423  0.440931
# 8      11721             11721       False   6.75   2.53  3.860756 -0.544986
# 9       4930              4930        True  18.14 -24.22  5.158088  1.975228
# 10     28768             28768       False   2.38 -11.71  1.849606  0.128471
# ...

# %%
freeze_frames.head(3)
# Out:
#                                                 data  \
# 0  [{'track_id': 12235, 'trackable_object': 12235...
# 1  [{'track_id': 12235, 'trackable_object': 12235...
# 2  [{'track_id': 12235, 'trackable_object': 12235...
#
#                                           possession  frame  \
# 0   {'group': 'away team', 'trackable_object': None}   4820
# 1  {'group': 'away team', 'trackable_object': 159...   4834
# 2   {'group': 'away team', 'trackable_object': None}   4854
#
#                             image_corners_projection               timestamp  \
# 0  [24.17946797703396, 39.0, 9.132086207144336, -... 2025-01-09 00:04:29.000
# 1  [47.42111418514567, 39.0, 19.524037390543953, ... 2025-01-09 00:04:30.400
# 2  [42.734535236816924, 39.0, 20.253145169781963,... 2025-01-09 00:04:32.400
#
#    period                              event_id  event_x  event_y  is_matched
# 0       1  54cbad0c-1f05-4708-9b7f-2cadeae0636b  35.3500  -27.710        True
# ...
